# %%
from autogluon.tabular import TabularPredictor

# %% [markdown]
# ## R1

# %%
h3predictor = TabularPredictor.load("AutogluonModels/ag-20240403_031417")
h3predictor.leaderboard()
# Out:
#                   model  score_val eval_metric  pred_time_val      fit_time  \
# 0   WeightedEnsemble_L2   0.310053    accuracy       1.053271  13458.233062
# 1              CatBoost   0.279365    accuracy       0.033065  13374.553806
# 2        ExtraTreesGini   0.277249    accuracy       0.144755      2.656589
# 3      RandomForestGini   0.275132    accuracy       0.143649      2.697209
# 4      RandomForestEntr   0.273016    accuracy       0.176549      2.829477
# 5       NeuralNetFastAI   0.269841    accuracy       0.025041     12.991843
# 6        NeuralNetTorch   0.267725    accuracy       0.013043     46.388631
# 7        ExtraTreesEntr   0.265608    accuracy       0.174646      2.776839
# 8            LightGBMXT   0.264550    accuracy       0.196028     12.621016
# 9              LightGBM   0.259259    accuracy       0.315286     14.250495
# 10        LightGBMLarge   0.255026    accuracy       0.365843     18.639942
# ...

# %%
h2predictor = TabularPredictor.load("AutogluonModels/ag-20240402_202402")
h2predictor.leaderboard()
# Out:
#                   model  score_val eval_metric  pred_time_val      fit_time  \
# 0   WeightedEnsemble_L2   0.308102    accuracy       0.910602  24190.749887
# 1              CatBoost   0.281450    accuracy       0.049124  24056.918139
# 2               XGBoost   0.265458    accuracy       0.029063     18.303659
# 3        NeuralNetTorch   0.262260    accuracy       0.015076     61.348103
# 4       NeuralNetFastAI   0.262260    accuracy       0.026055     16.985791
# 5      RandomForestEntr   0.255864    accuracy       0.144617      2.726330
# 6      RandomForestGini   0.254797    accuracy       0.128604      2.694840
# 7            LightGBMXT   0.253731    accuracy       0.382362     16.464594
# 8        ExtraTreesGini   0.248401    accuracy       0.171608      2.751128
# 9         LightGBMLarge   0.246269    accuracy       0.482668     18.929089
# 10       ExtraTreesEntr   0.245203    accuracy       0.144163      2.901055
# ...

# %% [markdown]
# ## R2

# %%
h3predictor = TabularPredictor.load("AutogluonModels/ag-20240402_151747")
h3predictor.leaderboard()
# Out:
#                   model  score_val eval_metric  pred_time_val      fit_time  \
# 0   WeightedEnsemble_L2   0.310053    accuracy       1.022828  13412.773364
# 1              CatBoost   0.279365    accuracy       0.036922  13328.361591
# 2        ExtraTreesGini   0.277249    accuracy       0.144077      2.694609
# 3      RandomForestGini   0.275132    accuracy       0.144275      2.673156
# 4      RandomForestEntr   0.273016    accuracy       0.142090      2.750170
# 5       NeuralNetFastAI   0.269841    accuracy       0.026077     13.518785
# 6        NeuralNetTorch   0.267725    accuracy       0.014070     47.174024
# 7        ExtraTreesEntr   0.265608    accuracy       0.222713      2.760505
# 8            LightGBMXT   0.264550    accuracy       0.223168     12.485083
# 9              LightGBM   0.259259    accuracy       0.237575     14.185408
# 10        LightGBMLarge   0.255026    accuracy       0.458430     18.834082
# ...

# %%
h2predictor = TabularPredictor.load("AutogluonModels/ag-20240402_082838")
h2predictor.leaderboard()
# Out:
#                   model  score_val eval_metric  pred_time_val      fit_time  \
# 0   WeightedEnsemble_L2   0.308102    accuracy       0.922197  24122.140528
# 1              CatBoost   0.281450    accuracy       0.063910  23983.949320
# 2               XGBoost   0.265458    accuracy       0.018998     19.915601
# 3        NeuralNetTorch   0.262260    accuracy       0.015086     62.686275
# 4       NeuralNetFastAI   0.262260    accuracy       0.024128     17.177742
# 5      RandomForestEntr   0.255864    accuracy       0.159967      3.191195
# 6      RandomForestGini   0.254797    accuracy       0.126475      2.979326
# 7            LightGBMXT   0.253731    accuracy       0.350253     16.499754
# 8        ExtraTreesGini   0.248401    accuracy       0.158608      2.583187
# 9         LightGBMLarge   0.246269    accuracy       0.467871     19.202733
# 10       ExtraTreesEntr   0.245203    accuracy       0.159714      2.708365
# ...

# %% [markdown]
# ## R3

# %%
h2predictor = TabularPredictor.load("AutogluonModels/ag-20240401_151002")
h2predictor.leaderboard()
# Out:
#                   model  score_val eval_metric  pred_time_val      fit_time  \
# 0   WeightedEnsemble_L2   0.308102    accuracy       0.859408  24108.001220
# 1              CatBoost   0.281450    accuracy       0.072014  23975.548904
# 2               XGBoost   0.265458    accuracy       0.037033     19.068156
# 3        NeuralNetTorch   0.262260    accuracy       0.015012     58.619782
# 4       NeuralNetFastAI   0.262260    accuracy       0.025034     16.346576
# 5      RandomForestEntr   0.255864    accuracy       0.192514      3.106287
# 6      RandomForestGini   0.254797    accuracy       0.156159      3.071390
# 7            LightGBMXT   0.253731    accuracy       0.324653     16.559680
# 8        ExtraTreesGini   0.248401    accuracy       0.129412      2.638611
# 9         LightGBMLarge   0.246269    accuracy       0.384275     19.249225
# 10             LightGBM   0.245203    accuracy       0.132527     13.922251
# ...
